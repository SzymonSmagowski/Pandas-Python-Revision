# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math as math

frame = pd.read_csv("./mcdonalds.csv")

# %%
frame.head()
# Out:
#     Category                              Item    Serving Size  Calories  \
# 0  Breakfast                      Egg McMuffin  4.8 oz (136 g)       300
# 1  Breakfast                 Egg White Delight  4.8 oz (135 g)       250
# 2  Breakfast                  Sausage McMuffin  3.9 oz (111 g)       370
# 3  Breakfast         Sausage McMuffin with Egg  5.7 oz (161 g)       450
# 4  Breakfast  Sausage McMuffin with Egg Whites  5.7 oz (161 g)       400
#
#    Calories from Fat  TotalFat  Total Fat (% Daily Value)  Saturated Fat  \
# 0                120      13.0                         20            5.0
# 1                 70       8.0                         12            3.0
# 2                200      23.0                         35            8.0
# 3                250      28.0                         43           10.0
# 4                210      23.0                         35            8.0
#
#    Saturated Fat (% Daily Value)  Trans Fat  ...  Carbohydrates  \
# ...

# %%
frame['Calories'] >= 400
# Out:
# 0      False
# 1      False
# 2      False
# 3       True
# 4       True
#        ...
# 255     True
# 256     True
# 257    False
# 258     True
# 259     True
# Name: Calories, Length: 260, dtype: bool

# %%
caloriesGreater = frame['Calories'] >= 400

# %%
totalFatLess = frame['TotalFat'] <= 20

# %%
frame[caloriesGreater].head()
# Out:
#     Category                                           Item    Serving Size  \
# 3  Breakfast                      Sausage McMuffin with Egg  5.7 oz (161 g)
# 4  Breakfast               Sausage McMuffin with Egg Whites  5.7 oz (161 g)
# 5  Breakfast                           Steak & Egg McMuffin  6.5 oz (185 g)
# 6  Breakfast  Bacon, Egg & Cheese Biscuit (Regular Biscuit)  5.3 oz (150 g)
# 7  Breakfast    Bacon, Egg & Cheese Biscuit (Large Biscuit)  5.8 oz (164 g)
#
#    Calories  Calories from Fat  TotalFat  Total Fat (% Daily Value)  \
# 3       450                250      28.0                         43
# 4       400                210      23.0                         35
# 5       430                210      23.0                         36
# 6       460                230      26.0                         40
# 7       520                270      30.0                         47
#
#    Saturated Fat  Saturated Fat (% Daily Value)  Trans Fat  ...  \
# ...

# %%
frame[totalFatLess]
# Out:
#                Category                                               Item  \
# 0             Breakfast                                       Egg McMuffin
# 1             Breakfast                                  Egg White Delight
# 8             Breakfast  Bacon, Egg & Cheese Biscuit with Egg Whites (R...
# 16            Breakfast   Southern Style Chicken Biscuit (Regular Biscuit)
# 20            Breakfast     Bacon, Egg & Cheese McGriddles with Egg Whites
# ..                  ...                                                ...
# 250  Smoothies & Shakes                            Shamrock Shake (Medium)
# 254  Smoothies & Shakes                McFlurry with M&M’s Candies (Snack)
# 255  Smoothies & Shakes                 McFlurry with Oreo Cookies (Small)
# 257  Smoothies & Shakes                 McFlurry with Oreo Cookies (Snack)
# 259  Smoothies & Shakes   McFlurry with Reese's Peanut Butter Cups (Snack)
#
#         Serving Size  Calories  Calories from Fat  TotalFat  \
# ...

# %%
isBreakfast = frame["Category"] == 'Breakfast'

# %%
frame[isBreakfast & caloriesGreater].head()
# Out:
#     Category                                           Item    Serving Size  \
# 3  Breakfast                      Sausage McMuffin with Egg  5.7 oz (161 g)
# 4  Breakfast               Sausage McMuffin with Egg Whites  5.7 oz (161 g)
# 5  Breakfast                           Steak & Egg McMuffin  6.5 oz (185 g)
# 6  Breakfast  Bacon, Egg & Cheese Biscuit (Regular Biscuit)  5.3 oz (150 g)
# 7  Breakfast    Bacon, Egg & Cheese Biscuit (Large Biscuit)  5.8 oz (164 g)
#
#    Calories  Calories from Fat  TotalFat  Total Fat (% Daily Value)  \
# 3       450                250      28.0                         43
# 4       400                210      23.0                         35
# 5       430                210      23.0                         36
# 6       460                230      26.0                         40
# 7       520                270      30.0                         47
#
#    Saturated Fat  Saturated Fat (% Daily Value)  Trans Fat  ...  \
# ...

# %%
frame[~isBreakfast].head()
# Out:
#        Category                                       Item    Serving Size  \
# 42  Beef & Pork                                    Big Mac  7.4 oz (211 g)
# 43  Beef & Pork                Quarter Pounder with Cheese  7.1 oz (202 g)
# 44  Beef & Pork        Quarter Pounder with Bacon & Cheese    8 oz (227 g)
# 45  Beef & Pork  Quarter Pounder with Bacon Habanero Ranch  8.3 oz (235 g)
# 46  Beef & Pork                     Quarter Pounder Deluxe  8.6 oz (244 g)
#
#     Calories  Calories from Fat  TotalFat  Total Fat (% Daily Value)  \
# 42       530                240      27.0                         42
# 43       520                240      26.0                         41
# 44       600                260      29.0                         45
# 45       610                280      31.0                         48
# 46       540                250      27.0                         42
#
#     Saturated Fat  Saturated Fat (% Daily Value)  Trans Fat  ...  \
# ...

# %% [markdown]
# ## Where and query

# %%
frame.where(frame['Calories'] > 500) # returning the same amount of rows
# Out:
#                Category                                               Item  \
# 0                   NaN                                                NaN
# 1                   NaN                                                NaN
# 2                   NaN                                                NaN
# 3                   NaN                                                NaN
# 4                   NaN                                                NaN
# ..                  ...                                                ...
# 255  Smoothies & Shakes                 McFlurry with Oreo Cookies (Small)
# 256  Smoothies & Shakes                McFlurry with Oreo Cookies (Medium)
# 257                 NaN                                                NaN
# 258  Smoothies & Shakes  McFlurry with Reese's Peanut Butter Cups (Medium)
# 259                 NaN                                                NaN
#
#         Serving Size  Calories  Calories from Fat  TotalFat  \
# ...

# %%
frame.query('Category == "Desserts"')
# Out:
#      Category                   Item     Serving Size  Calories  \
# 103  Desserts        Baked Apple Pie    2.7 oz (77 g)       250
# 104  Desserts  Chocolate Chip Cookie  1 cookie (33 g)       160
# 105  Desserts  Oatmeal Raisin Cookie  1 cookie (33 g)       150
# 106  Desserts    Kids Ice Cream Cone      1 oz (29 g)        45
# 107  Desserts       Hot Fudge Sundae   6.3 oz (179 g)       330
# 108  Desserts     Hot Caramel Sundae   6.4 oz (182 g)       340
# 109  Desserts      Strawberry Sundae   6.3 oz (178 g)       280
#
#      Calories from Fat  TotalFat  Total Fat (% Daily Value)  Saturated Fat  \
# 103                110      13.0                         19            7.0
# 104                 70       8.0                         12            3.5
# 105                 50       6.0                          9            2.5
# 106                 10       1.5                          2            1.0
# 107                 80       9.0                         14            7.0
# ...

# %%
frame.query('Category in ["Desserts","Beverages"]')
# Out:
#       Category                               Item       Serving Size  \
# 103   Desserts                    Baked Apple Pie      2.7 oz (77 g)
# 104   Desserts              Chocolate Chip Cookie    1 cookie (33 g)
# 105   Desserts              Oatmeal Raisin Cookie    1 cookie (33 g)
# 106   Desserts                Kids Ice Cream Cone        1 oz (29 g)
# 107   Desserts                   Hot Fudge Sundae     6.3 oz (179 g)
# 108   Desserts                 Hot Caramel Sundae     6.4 oz (182 g)
# 109   Desserts                  Strawberry Sundae     6.3 oz (178 g)
# 110  Beverages          Coca-Cola Classic (Small)       16 fl oz cup
# 111  Beverages         Coca-Cola Classic (Medium)       21 fl oz cup
# 112  Beverages          Coca-Cola Classic (Large)       30 fl oz cup
# 113  Beverages          Coca-Cola Classic (Child)       12 fl oz cup
# 114  Beverages                  Diet Coke (Small)       16 fl oz cup
# 115  Beverages                 Diet Coke (Medium)       21 fl oz cup
# ...

# %% [markdown]
# ## Other methods

# %%
color = ['green','green', 'blue','blue','red','red','white']
size= ['S','S','S','M','M','M','L']
gender = ['M','W','M','W','M','W','U']
clothes = pd.DataFrame({'color':color,'size':size,'gender':gender})

# %%
clothes
# Out:
#    color size gender
# 0  green    S      M
# 1  green    S      W
# 2   blue    S      M
# 3   blue    M      W
# 4    red    M      M
# 5    red    M      W
# 6  white    L      U

# %%
clothes['color'].isin(['green','blue'])
# Out:
# 0     True
# 1     True
# 2     True
# 3     True
# 4    False
# 5    False
# 6    False
# Name: color, dtype: bool

# %%
clothes[clothes['color'].isin(['green','blue'])]
# Out:
#    color size gender
# 0  green    S      M
# 1  green    S      W
# 2   blue    S      M
# 3   blue    M      W

# %%
clothes.loc[6,'size'] = np.NaN
clothes.loc[1,'size'] = np.NaN

# %%
clothes
# Out:
#    color size gender
# 0  green    S      M
# 1  green  NaN      W
# 2   blue    S      M
# 3   blue    M      W
# 4    red    M      M
# 5    red    M      W
# 6  white  NaN      U

# %%
clothes['size'].notnull()
# Out:
# 0     True
# 1    False
# 2     True
# 3     True
# 4     True
# 5     True
# 6    False
# Name: size, dtype: bool

# %%
clothes['size'].isnull()
# Out:
# 0    False
# 1     True
# 2    False
# 3    False
# 4    False
# 5    False
# 6     True
# Name: size, dtype: bool

# %%
frame['Calories'].between(300,401)
# Out:
# 0       True
# 1      False
# 2       True
# 3      False
# 4       True
#        ...
# 255    False
# 256    False
# 257     True
# 258    False
# 259    False
# Name: Calories, Length: 260, dtype: bool

# %% [markdown]
# ## Duplicates

# %%
clothes['color'].is_unique
# Out:
# False

# %%
clothes['color'].unique()
# Out:
# array(['green', 'blue', 'red', 'white'], dtype=object)

# %%
clothes['color'].nunique()
# Out:
# 4

# %%
clothes['size'].unique()
# Out:
# array(['S', nan, 'M'], dtype=object)

# %%
clothes['size'].nunique()
# Out:
# 2

# %%
len(clothes['size'].unique())
# Out:
# 3

# %%
clothes['color'].duplicated(keep='first') # looking for duplicates
# Out:
# 0    False
# 1     True
# 2    False
# 3     True
# 4    False
# 5     True
# 6    False
# Name: color, dtype: bool

# %%
clothes['color'].duplicated(keep='last')
# Out:
# 0     True
# 1    False
# 2     True
# 3    False
# 4     True
# 5    False
# 6    False
# Name: color, dtype: bool

# %%
clothes[clothes['color'].duplicated(keep='first')]
# Out:
#    color size gender
# 1  green  NaN      W
# 3   blue    M      W
# 5    red    M      W

# %%
clothes.drop_duplicates(subset='color',keep='first')
# Out:
#    color size gender
# 0  green    S      M
# 2   blue    S      M
# 4    red    M      M
# 6  white  NaN      U

# %%
clothes.drop_duplicates(subset=['color','size'],keep='first')
# Out:
#    color size gender
# 0  green    S      M
# 1  green  NaN      W
# 2   blue    S      M
# 3   blue    M      W
# 4    red    M      M
# 6  white  NaN      U
