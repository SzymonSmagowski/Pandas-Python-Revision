# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math as math
frame = pd.read_csv("./Canadian Railway Crossing Incidents.csv")

# %%
frame.head()
# Out:
#          Region         EventType  Public automated  Public passive  Private  \
# 0  Newfoundland         Accidents                 0               0        0
# 1  Newfoundland        Fatalities                 0               0        0
# 2  Newfoundland  Serious injuries                 0               0        0
# 3   Nova Scotia         Accidents                 1               0        0
# 4   Nova Scotia        Fatalities                 0               0        0
#
#    Farm
# 0     0
# 1     0
# 2     0
# 3     0
# 4     0

# %%
frame.set_index(keys=['Region','EventType'],inplace=True)
frame.head()
# Out:
#                                Public automated  Public passive  Private  Farm
# Region       EventType
# Newfoundland Accidents                        0               0        0     0
#              Fatalities                       0               0        0     0
#              Serious injuries                 0               0        0     0
# Nova Scotia  Accidents                        1               0        0     0
#              Fatalities                       0               0        0     0

# %%
frame.sort_index(ascending=[True,False])
# Out:
#                                         Public automated  Public passive  \
# Region                EventType
# Alberta               Serious injuries                 0               1
#                       Fatalities                       0               0
#                       Accidents                        3               7
# British Columbia      Serious injuries                 3               0
#                       Fatalities                       0               0
#                       Accidents                        4               1
# Manitoba              Serious injuries                 0               0
#                       Fatalities                       0               1
#                       Accidents                        1               3
# New Brunswick         Serious injuries                 0               0
#                       Fatalities                       0               0
# ...
