# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math as math
frame = pd.read_csv("./insurance.csv")

# %%
frame.head()
# Out:
#    ID  District   Group    Age  Holders  Claims
# 0   1         1     <1l    <25      197      38
# 1   2         1     <1l  25-29      264      35
# 2   3         1     <1l  30-35      246      20
# 3   4         1     <1l    >35     1680     156
# 4   5         1  1-1.5l    <25      284      63

# %%
frame.drop(axis='rows',labels=[3,4],inplace=True)

# %%
frame.head()
# Out:
#    ID  District   Group    Age  Holders  Claims
# 2   3         1     <1l  30-35      246      20
# 5   6         1  1-1.5l  25-29      536      84
# 6   7         1  1-1.5l  30-35      696      89
# 7   8         1  1-1.5l    >35     3582     400
# 8   9         1  1.5-2l    <25      133      19

# %%
frame.append({'ID':'1','District':'1','Group':'low','Age':'tmp','Holders':'non','Claims':'11'},ignore_index=True)
# Out:
#     ID District   Group    Age Holders Claims
# 0    3        1     <1l  30-35     246     20
# 1    6        1  1-1.5l  25-29     536     84
# 2    7        1  1-1.5l  30-35     696     89
# 3    8        1  1-1.5l    >35    3582    400
# 4    9        1  1.5-2l    <25     133     19
# ..  ..      ...     ...    ...     ...    ...
# 56  61        4     >2l    <25       3      0
# 57  62        4     >2l  25-29      16      6
# 58  63        4     >2l  30-35      25      8
# 59  64        4     >2l    >35     114     33
# 60   1        1     low    tmp     non     11
#
# [61 rows x 6 columns]

# %%
frame
# Out:
#     ID  District   Group    Age  Holders  Claims
# 2    3         1     <1l  30-35      246      20
# 5    6         1  1-1.5l  25-29      536      84
# 6    7         1  1-1.5l  30-35      696      89
# 7    8         1  1-1.5l    >35     3582     400
# 8    9         1  1.5-2l    <25      133      19
# 9   10         1  1.5-2l  25-29      286      52
# 10  11         1  1.5-2l  30-35      355      74
# 11  12         1  1.5-2l    >35     1640     233
# 12  13         1     >2l    <25       24       4
# 13  14         1     >2l  25-29       71      18
# 14  15         1     >2l  30-35       99      19
# 15  16         1     >2l    >35      452      77
# 16  17         2     <1l    <25       85      22
# 17  18         2     <1l  25-29      139      19
# 18  19         2     <1l  30-35      151      22
# 19  20         2     <1l    >35      931      87
# 20  21         2  1-1.5l    <25      149      25
# 21  22         2  1-1.5l  25-29      313      51
# ...

# %% [markdown]
# ## append works on copy, it returns a new object

# %%
changed = frame.append({'ID':'1','District':'1','Group':'low','Age':'tmp','Holders':'non','Claims':'11'},ignore_index=True)
changed
# Out:
#     ID District   Group    Age Holders Claims
# 0    3        1     <1l  30-35     246     20
# 1    6        1  1-1.5l  25-29     536     84
# 2    7        1  1-1.5l  30-35     696     89
# 3    8        1  1-1.5l    >35    3582    400
# 4    9        1  1.5-2l    <25     133     19
# ..  ..      ...     ...    ...     ...    ...
# 56  61        4     >2l    <25       3      0
# 57  62        4     >2l  25-29      16      6
# 58  63        4     >2l  30-35      25      8
# 59  64        4     >2l    >35     114     33
# 60   1        1     low    tmp     non     11
#
# [61 rows x 6 columns]
