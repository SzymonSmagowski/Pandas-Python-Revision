# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math as math
cat1 = pd.read_csv("./categories_del_1.csv",usecols=['CategoryID','CategoryName'])
cat2 = pd.read_csv("./categories_del_2.csv",usecols=['CategoryID','CategoryName'])

# %%
cat1
# Out:
#    CategoryID    CategoryName
# 0           2      Condiments
# 1           3     Confections
# 2           4  Dairy Products
# 3           5  Grains/Cereals
# 4           6    Meat/Poultry
# 5           7         Produce
# 6           8         Seafood

# %%
cat2
# Out:
#    CategoryID    CategoryName
# 0           1       Beverages
# 1           2      Condiments
# 2           3     Confections
# 3           4  Dairy Products
# 4           7         Produce
# 5           8         Seafood

# %%
cat1.merge(cat2) # inner join
# Out:
#    CategoryID    CategoryName
# 0           2      Condiments
# 1           3     Confections
# 2           4  Dairy Products
# 3           7         Produce
# 4           8         Seafood

# %%
cat1.merge(cat2, on='CategoryID')
# Out:
#    CategoryID  CategoryName_x  CategoryName_y
# 0           2      Condiments      Condiments
# 1           3     Confections     Confections
# 2           4  Dairy Products  Dairy Products
# 3           7         Produce         Produce
# 4           8         Seafood         Seafood

# %%
cat1.merge(cat2, on='CategoryID', suffixes=['_1','_2'])
# Out:
#    CategoryID  CategoryName_1  CategoryName_2
# 0           2      Condiments      Condiments
# 1           3     Confections     Confections
# 2           4  Dairy Products  Dairy Products
# 3           7         Produce         Produce
# 4           8         Seafood         Seafood

# %%
cat1.merge(cat2, how='outer',on='CategoryID', suffixes=['_1','_2']) # how='left' left join, right accordingly
# Out:
#    CategoryID  CategoryName_1  CategoryName_2
# 0           2      Condiments      Condiments
# 1           3     Confections     Confections
# 2           4  Dairy Products  Dairy Products
# 3           5  Grains/Cereals             NaN
# 4           6    Meat/Poultry             NaN
# 5           7         Produce         Produce
# 6           8         Seafood         Seafood
# 7           1             NaN       Beverages

# %%
cat1.merge(cat2, how='outer',on='CategoryID', suffixes=['_1','_2'], indicator=True)
# Out:
#    CategoryID  CategoryName_1  CategoryName_2      _merge
# 0           2      Condiments      Condiments        both
# 1           3     Confections     Confections        both
# 2           4  Dairy Products  Dairy Products        both
# 3           5  Grains/Cereals             NaN   left_only
# 4           6    Meat/Poultry             NaN   left_only
# 5           7         Produce         Produce        both
# 6           8         Seafood         Seafood        both
# 7           1             NaN       Beverages  right_only

# %%
cat_merged = cat1.merge(cat2, how='outer',on='CategoryID', suffixes=['_1','_2'], indicator=True)

# %%
filter = cat_merged['_merge'] == 'left_only'
cat_merged[filter]
# Out:
#    CategoryID  CategoryName_1 CategoryName_2     _merge
# 3           5  Grains/Cereals            NaN  left_only
# 4           6    Meat/Poultry            NaN  left_only

# %% [markdown]
# ## Advanced options of merge()

# %%
products = pd.read_csv("./products.csv",usecols=['ProductID','ProductName','CategoryID','UnitPrice'])
categories = pd.read_csv("./categories1.csv",usecols=['CategoryID','CategoryName','Description'])

# %%
products.head()
# Out:
#    ProductID                   ProductName  CategoryID  UnitPrice
# 0          1                          Chai           1      18.00
# 1          2                         Chang           1      19.00
# 2          3                 Aniseed Syrup           2      10.00
# 3          4  Chef Anton's Cajun Seasoning           2      22.00
# 4          5        Chef Anton's Gumbo Mix           2      21.35

# %%
categories.head()
# Out:
#    CategoryID    CategoryName              Description
# 0           1       Beverages              Soft drinks
# 1           2      Condiments  Sweet and savory sauces
# 2           3     Confections                 Desserts
# 3           4  Dairy Products                  Cheeses
# 4           5  Grains/Cereals                   Breads

# %%
products.merge(right=categories, on='CategoryID').head()
# Out:
#    ProductID         ProductName  CategoryID  UnitPrice CategoryName  \
# 0          1                Chai           1       18.0    Beverages
# 1          2               Chang           1       19.0    Beverages
# 2         24  Guaraná Fantástica           1        4.5    Beverages
# 3         34       Sasquatch Ale           1       14.0    Beverages
# 4         35      Steeleye Stout           1       18.0    Beverages
#
#    Description
# 0  Soft drinks
# 1  Soft drinks
# 2  Soft drinks
# 3  Soft drinks
# 4  Soft drinks

# %%
categories.rename({'CategoryID':'ID'},axis='columns',inplace=True)

# %%
categories.head()
# Out:
#    ID    CategoryName              Description
# 0   1       Beverages              Soft drinks
# 1   2      Condiments  Sweet and savory sauces
# 2   3     Confections                 Desserts
# 3   4  Dairy Products                  Cheeses
# 4   5  Grains/Cereals                   Breads

# %%
products.merge(right=categories,left_on='CategoryID',right_on='ID').head()
# Out:
#    ProductID         ProductName  CategoryID  UnitPrice  ID CategoryName  \
# 0          1                Chai           1       18.0   1    Beverages
# 1          2               Chang           1       19.0   1    Beverages
# 2         24  Guaraná Fantástica           1        4.5   1    Beverages
# 3         34       Sasquatch Ale           1       14.0   1    Beverages
# 4         35      Steeleye Stout           1       18.0   1    Beverages
#
#    Description
# 0  Soft drinks
# 1  Soft drinks
# 2  Soft drinks
# 3  Soft drinks
# 4  Soft drinks

# %%
categories.set_index('ID',inplace=True)

# %%
categories.head()
# Out:
#       CategoryName              Description
# ID
# 1        Beverages              Soft drinks
# 2       Condiments  Sweet and savory sauces
# 3      Confections                 Desserts
# 4   Dairy Products                  Cheeses
# 5   Grains/Cereals                   Breads

# %%
products.merge(right=categories,left_on='CategoryID',right_index=True, suffixes=['_prod','_cat'],sort=True).head()
# Out:
#     ProductID         ProductName  CategoryID  UnitPrice CategoryName  \
# 0           1                Chai           1       18.0    Beverages
# 1           2               Chang           1       19.0    Beverages
# 23         24  Guaraná Fantástica           1        4.5    Beverages
# 33         34       Sasquatch Ale           1       14.0    Beverages
# 34         35      Steeleye Stout           1       18.0    Beverages
#
#     Description
# 0   Soft drinks
# 1   Soft drinks
# 23  Soft drinks
# 33  Soft drinks
# 34  Soft drinks
